# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, ndcg_score, precision_recall_curve
from sklearn.metrics import roc_curve, average_precision_score
from sklearn.metrics import RocCurveDisplay, PrecisionRecallDisplay
import pandas as pd

# %%
y_ = pd.read_excel('./out/kws_dp_GCN_marked.xlsx').fillna(0)

# %%
y_['label_f'] = y_['label_f'].astype(bool)
y_['label_t'] = ~y_['label_f']

# %%
y_
# Out:
#                        Unnamed: 0  score  Unnamed: 2  label_f  repeat  label_t
# 0            SEMICONDUCTOR DEVICE   2655         0.0    False     0.0     True
# 1            MANUFACTURING METHOD   2593         0.0     True     0.0    False
# 2               PRODUCTION METHOD   1748         0.0     True     0.0    False
# 3                       FUEL CELL   1597         0.0    False     0.0     True
# 4               RESIN COMPOSITION   1170         0.0    False     0.0     True
# ...                           ...    ...         ...      ...     ...      ...
# 1054              NONWOVEN FABRIC     21         0.0    False     0.0     True
# 1055  MARTENSITIC STAINLESS STEEL     21         0.0    False     0.0     True
# 1056        OPTOELECTRONIC MODULE     21         0.0    False     0.0     True
# 1057      LASER PROCESSING METHOD     21         0.0     True     0.0    False
# 1058          TARGET NUCLEIC ACID     21         0.0    False     0.0     True
#
# [1059 rows x 6 columns]

# %%
y_pred = pd.read_excel('./out/kws_dp_GCN.xlsx')

# %%
y_pred.loc[:200, 'label'] = 1
y_pred = y_pred.fillna(0)
y_pred['label'] = y_pred['label'].astype(bool)

# %%
y_pred
# Out:
#                           Unnamed: 0  score  label
# 0                IMAGE PICKUP DEVICE     32   True
# 1                  BIOLOGICAL SAMPLE     67   True
# 2                ORAL ADMINISTRATION     38   True
# 3                         LEAD FRAME     46   True
# 4                   IMPROVED PROCESS     34   True
# ...                              ...    ...    ...
# 1054                 IMMUNE RESPONSE     76  False
# 1055             TARGET NUCLEIC ACID     21  False
# 1056               HYDROGEN CHLORIDE     31  False
# 1057             SELECTIVE OXIDATION     23  False
# 1058  ORGANIC LIGHT EMITTING DISPLAY     80  False
#
# [1059 rows x 3 columns]

# %%
y_t = pd.merge(y_pred, y_, how='left')

# %%
y_t
# Out:
#                           Unnamed: 0  score  label  Unnamed: 2  label_f  \
# 0                IMAGE PICKUP DEVICE     32   True         0.0    False
# 1                  BIOLOGICAL SAMPLE     67   True         0.0     True
# 2                ORAL ADMINISTRATION     38   True         0.0    False
# 3                         LEAD FRAME     46   True         0.0    False
# 4                   IMPROVED PROCESS     34   True         0.0     True
# ...                              ...    ...    ...         ...      ...
# 1054                 IMMUNE RESPONSE     76  False         0.0    False
# 1055             TARGET NUCLEIC ACID     21  False         0.0    False
# 1056               HYDROGEN CHLORIDE     31  False         0.0    False
# 1057             SELECTIVE OXIDATION     23  False         0.0     True
# 1058  ORGANIC LIGHT EMITTING DISPLAY     80  False         0.0    False
#
#       repeat  label_t
# 0        2.0     True
# 1        0.0    False
# 2        0.0     True
# 3        0.0     True
# 4        0.0    False
# ...      ...      ...
# 1054     0.0     True
# 1055     0.0     True
# 1056     0.0     True
# 1057     0.0    False
# 1058     0.0     True
#
# [1059 rows x 7 columns]

# %%
print('precision:', precision_score(y_t['label_t'], y_t['label']))
print('recall:', recall_score( y_t['label_t'], y_t['label']))
print('f1 score:', f1_score( y_t['label_t'], y_t['label']))
print('accuracy:', accuracy_score( y_t['label_t'], y_t['label']))
# Out:
# precision: 0.7661691542288557
# recall: 0.19543147208121828
# f1 score: 0.31142568250758346
# accuracy: 0.35694050991501414

# %%
y_.loc[:200, 'la'] = 1
y_ = y_.fillna(0)
y_['la'] = y_['la'].astype(bool)

# %%
y_
# Out:
#                        Unnamed: 0  score  Unnamed: 2  label_f  repeat  \
# 0            SEMICONDUCTOR DEVICE   2655         0.0    False     0.0
# 1            MANUFACTURING METHOD   2593         0.0     True     0.0
# 2               PRODUCTION METHOD   1748         0.0     True     0.0
# 3                       FUEL CELL   1597         0.0    False     0.0
# 4               RESIN COMPOSITION   1170         0.0    False     0.0
# ...                           ...    ...         ...      ...     ...
# 1054              NONWOVEN FABRIC     21         0.0    False     0.0
# 1055  MARTENSITIC STAINLESS STEEL     21         0.0    False     0.0
# 1056        OPTOELECTRONIC MODULE     21         0.0    False     0.0
# 1057      LASER PROCESSING METHOD     21         0.0     True     0.0
# 1058          TARGET NUCLEIC ACID     21         0.0    False     0.0
#
#       label_t     la
# 0        True   True
# 1       False   True
# 2       False   True
# 3        True   True
# 4        True   True
# ...       ...    ...
# 1054     True  False
# 1055     True  False
# 1056     True  False
# 1057    False  False
# 1058     True  False
#
# [1059 rows x 7 columns]

# %%
print('precision:', precision_score(y_['label_t'], y_['la']))
print('recall:', recall_score(y_['label_t'], y_['la']))
print('f1 score:', f1_score(y_['label_t'], y_['la']))
print('accuracy:', accuracy_score(y_['label_t'], y_['la']))
# Out:
# precision: 0.845771144278607
# recall: 0.21573604060913706
# f1 score: 0.34378159757330645
# accuracy: 0.3871576959395656

# %%
def eval(y_file, y_pred_file, name, div= 400):
    y_ = pd.read_excel(y_file).fillna(0)
    y_['label_f'] = y_['label_f'].astype(bool)
    y_['label_t'] = ~y_['label_f']
    
    y_pred = pd.read_excel(y_pred_file)
    y_pred.loc[:div, 'label'] = 1
    y_pred = y_pred.fillna(0)
    y_pred['label'] = y_pred['label'].astype(bool)
    
    y_t = pd.merge(y_pred, y_, how='left')
#     print(y_t)
    
    precision = precision_score(y_t['label_t'], y_t['label'])
    recall = recall_score( y_t['label_t'], y_t['label'])
    f1 = f1_score( y_t['label_t'], y_t['label'])
    acc = accuracy_score( y_t['label_t'], y_t['label'])
    ap = average_precision_score( y_t['label_t'], y_t['label'])
                            
#     print('precision: ', precision_score(y_t['label_t'], y_t['label']))
#     print('recall:', recall_score( y_t['label_t'], y_t['label']))
#     print('f1 score:', f1_score( y_t['label_t'], y_t['label']))
#     print('accuracy:', accuracy_score( y_t['label_t'], y_t['label']))
#     print('NDCG:', ndcg_score( y_t['label_t'], y_t['label']))
#     fpr, tpr, _ = roc_curve( y_t['label_t'], y_t['label'], pos_label=True)
#     roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr).plot()

    prec, recalls, _ = precision_recall_curve(y_t['label_t'], y_t['label'],pos_label=True)
    pr_display = PrecisionRecallDisplay(precision=prec, recall=recalls, estimator_name=name).plot()
#     pr_display.savefig()
    return {'precision':precision, 'recall':recall, 'f1_score':f1, 'accuracy':acc, 'average_precision_score':ap}

# %%
metrics_list = []

# %%
metrics_list.append(eval('./out/kws_dp_GCN_marked.xlsx', './out/kws_dp_GCN.xlsx', 'dp_GCN'))
metrics_list.append(eval('./out/kw_dp_term_frequency_marked.xlsx', './out/kw_dp_term_frequency.xlsx', 'dp_term_frequency'))
metrics_list.append(eval('./out/kws_dp_pagerank_marked.xlsx', './out/kws_dp_pagerank.xlsx','dp_pagerank'))
metrics_list.append(eval('./out/kws_textrank_marked.xlsx', './out/kws_textrank.xlsx', 'textrank'))
metrics_list.append(eval('./out/kws_tfidf_marked.xlsx', './out/kws_tfidf.xlsx', 'tfidf'))

# %%
# eval('./out/kws_dp_GCN_marked.xlsx', './out/kws_dp_GCN_top1_2_pca2.xlsx')

# %%
# metrics_list

# %%
df = pd.DataFrame(metrics_list, index=['dp_GCN', 'dp_term_frequency', 'dp_pagerank', 'textrank', 'tfidf'])

# %%
df
# Out:
#                    precision    recall  f1_score  accuracy  \
# dp_GCN              0.765586  0.389594  0.516400  0.457035
# dp_term_frequency   0.750623  0.420979  0.539427  0.486000
# dp_pagerank         0.556110  0.398927  0.464583  0.486000
# textrank            0.309227  0.262712  0.284078  0.375000
# tfidf               0.625935  0.405493  0.492157  0.482000
#
#                    average_precision_score
# dp_GCN                            0.752470
# dp_term_frequency                 0.729997
# dp_pagerank                       0.557847
# textrank                          0.429238
# tfidf                             0.621812

# %%
df.to_excel('./out/metrics_400.xlsx')

# %%
def plot_precision_recall_curve(y_true, y_predicted, out_path):
    """Create a PNG with the precision-recall curve for our predictions."""

    print("Calculate precision recall curve.")
    precision, recall, thresholds = metrics.precision_recall_curve(y_true,
                                                                   y_predicted)

#     # Save the raw precision and recall results to a pickle since we might want
#     # to analyse them later.
#     out_file = os.path.join(out_path, "precision_recall.pickle")
#     with open(out_file, "wb") as out:
#         pickle.dump({
#             "precision": precision,
#             "recall": recall,
#             "thresholds": thresholds
#         }, out)

    # Create the precision-recall curve.
    out_file = os.path.join(out_path, "./out/precision_recall.png")
    plt.clf()
    plt.plot(recall, precision, label="Precision-Recall curve")
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.savefig(out_file)
